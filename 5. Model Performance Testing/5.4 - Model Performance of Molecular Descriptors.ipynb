# %% [markdown]
# # Model Performance on test set

# %%
# assign column names as the 0% variance
column_names = X_var_0.columns

# %%
# set features as the 0% variance features
X_test_features = X_test[column_names[:]]
X_test_features.head()
# Out:
#            AM1_E   AM1_Eele      AM1_HF  AM1_HOMO    AM1_IP  AM1_LUMO  \
# 951   -77978.922 -484111.81 -100.922530  -9.29992   9.29992  -0.82685
# 1059  -55631.867 -308149.69   89.680222  -8.61687   8.61687  -0.80911
# 1269  -56866.672 -277625.44 -150.823200 -10.08352  10.08352   0.94324
# 236  -112177.680 -799216.75  -15.559040  -8.43825   8.43825  -0.71327
# 942   -80280.555 -573363.69   -1.698020  -9.58055   9.58055  -1.28814
#
#       AM1_dipole        ASA       ASA+       ASA-  ...  vsurf_Wp2  vsurf_Wp3  \
# 951     4.235959  518.88654  322.45627  196.43025  ...    392.000    114.500
# 1059    4.261133  435.59259  224.47331  211.11928  ...    386.375    100.875
# 1269    4.497928  393.40744  269.61371  123.79372  ...    299.375    123.750
# 236     1.242920  661.53381  406.86914  254.66469  ...    505.625     88.375
# 942     4.811505  461.10413  313.97968  141.15770  ...    374.625     77.625
#
#       vsurf_Wp4  vsurf_Wp5  vsurf_Wp6  vsurf_Wp7  vsurf_Wp8  weinerPath  \
# 951      35.750     14.375      4.625      0.500        0.0         706
# 1059     38.625     19.875      9.500      3.250        0.5         411
# 1269     48.125     19.875      5.875      0.125        0.0         235
# 236      16.625      6.250      1.500      0.000        0.0        2452
# 942      16.375      6.250      1.500      0.000        0.0         733
#
#       weinerPol  zagreb
# 951          21      86
# 1059         15      72
# 1269         12      48
# 236          43     148
# 942          35     108
#
# [5 rows x 349 columns]

# %%
# apply rf to obtain performance of best feature combination on test set
rf = RandomForestClassifier(n_estimators = 100, random_state= 1)
rf.fit(X_var_0, y_train)

#make predictions
y_score = rf.predict(X_test_features)
y_pred_proba = rf.predict_proba(X_test_features)[::,1]

# calculate performance matrices
print("=== Confusion Matrix ===")
CM = confusion_matrix(y_test, y_score)
print(CM)
print('\n')
print("=== Classification Report ===")
print(classification_report(y_test, y_score))
print('\n')
print("=== AUC Score ===")
print(roc_auc_score(y_test, y_pred_proba))
# Out:
# === Confusion Matrix ===
# [[222  12]
#  [ 28  24]]
#
#
# === Classification Report ===
#               precision    recall  f1-score   support
#
#            0       0.89      0.95      0.92       234
#            1       0.67      0.46      0.55        52
#
#     accuracy                           0.86       286
#    macro avg       0.78      0.71      0.73       286
# weighted avg       0.85      0.86      0.85       286
#
#
#
# === AUC Score ===
# 0.8243343195266272

# %%
# apply rf algorithm to rank the features based on their importance
feature_imp = pd.Series(rf.feature_importances_,index=column_names).sort_values(ascending=False)
feature_imp.head(50)
# Out:
# a_nN              0.030536
# GCUT_SLOGP_0      0.017252
# GCUT_PEOE_0       0.014878
# PEOE_VSA+4        0.013497
# MNDO_HF           0.010870
# h_pavgQ           0.010509
# a_ICM             0.009103
# GCUT_SMR_1        0.008872
# PEOE_VSA-6        0.008245
# SMR_VSA3          0.007914
# PEOE_VSA_PPOS     0.007602
# BCUT_SMR_1        0.007363
# PEOE_VSA_FPOL     0.006910
# h_pKb             0.006779
# GCUT_PEOE_1       0.006661
# E_nb              0.006600
# GCUT_PEOE_3       0.005852
# PM3_LUMO          0.005590
# npr2              0.005585
# PEOE_VSA_FPPOS    0.005485
# vsurf_Wp2         0.005480
# RPC-              0.005135
# E_ele             0.005128
# PEOE_PC-          0.005083
# chiral_u          0.004969
# vsurf_EDmin1      0.004968
# std_dim3          0.004933
# MNDO_HOMO         0.004925
# BCUT_SLOGP_0      0.004922
# h_logD            0.004847
# dipole            0.004811
# GCUT_PEOE_2       0.004804
# dipoleY           0.004760
# PM3_HF            0.004730
# E_oop             0.004682
# AM1_HOMO          0.004633
# GCUT_SLOGP_3      0.004594
# SMR_VSA6          0.004541
# npr1              0.004501
# chiral            0.004442
# PEOE_VSA-0        0.004405
# BCUT_PEOE_1       0.004382
# PEOE_VSA_FNEG     0.004345
# AM1_HF            0.004319
# BCUT_PEOE_2       0.004258
# PEOE_VSA+1        0.004201
# vsurf_Wp5         0.004148
# BCUT_PEOE_0       0.004140
# PEOE_RPC+         0.004105
# BCUT_PEOE_3       0.004089
# dtype: float64
